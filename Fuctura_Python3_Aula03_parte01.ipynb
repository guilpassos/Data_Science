# %% [markdown]
# <a href="https://colab.research.google.com/github/guilpassos/Fuctura_Data_Science/blob/main/Fuctura_Python3_Aula03_parte01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#O que já sabemos?
empresas = ['Apple', 'Google', 'Amazon',
            'Microsoft', 'Tencent', "McDonald's",
            'Visa', 'Facebook', 'Alibaba', 'Louis Vuitton']

# %%
bilhoes = [947.062, 819.573, 705.646,
           611.460, 214.023, 196.526,
           191.032, 186.421, 169.966,
           124.273]

# %%
#já é possivel plotar, só com as variaveis
plt.plot(empresas, bilhoes)

# %%
plt.plot(empresas, bilhoes)
plt.title('Empresas mais ricas do mundo')
# Out:
# Text(0.5, 1.0, 'Empresas mais ricas do mundo')

# %%
plt.plot(empresas, bilhoes)
plt.title('Empresas mais ricas do mundo')
plt.xlabel('Empresas')
# Out:
# Text(0.5, 0, 'Empresas')

# %%
plt.plot(empresas, bilhoes)
plt.title('Empresas mais ricas do mundo')
plt.xlabel('Empresas')
plt.ylabel('Bilhões')
# Out:
# Text(0, 0.5, 'Bilhões')

# %%
#Redimnesionamento
plt.rcParams["figure.figsize"] = (15, 8)
plt.plot(empresas, bilhoes)
plt.title('Empresas mais ricas do mundo')
plt.xlabel('Empresas')
plt.ylabel('Bilhões')
plt.show()

# %%
#conhecendo o frontsize
plt.plot(empresas, bilhoes)
plt.title('Empresas mais ricas do mundo', fontsize=25)
plt.xlabel('Empresas', fontsize=20)
plt.ylabel('Bilhões', fontsize=20)
plt.show()

# %%
#mudando a cor e legendado
plt.plot(empresas, bilhoes, color = 'green')
plt.title('Empresas mais ricas do mundo', fontsize=25)
plt.xlabel('Empresas', fontsize=20)
plt.ylabel('Bilhões', fontsize=20)
plt.legend(['Bilhões de dólares'], loc = 'right', fontsize=15)
plt.show()

# %%
#aumentar a espessura da linha lw
plt.plot(empresas, bilhoes, color = 'green', lw = 5)
plt.title('Empresas mais ricas do mundo', fontsize=25)
plt.xlabel('Empresas', fontsize=20)
plt.ylabel('Bilhões', fontsize=20)
plt.legend(['Bilhões de dólares'], loc = 'right', fontsize=15)
plt.show()

# %%
#adicionar um marcador
plt.plot(empresas, bilhoes, color = 'blue', marker = 'o')
plt.title('Empresas mais ricas do mundo', fontsize=25)
plt.xlabel('Empresas', fontsize=20)
plt.ylabel('Bilhões', fontsize=20)
plt.legend(['Bilhões de dólares'], loc = 'right', fontsize=15)
plt.show()

# %%
#adicionando linhas de grade
plt.plot(empresas, bilhoes, color = 'blue', marker = 'o')
plt.title('Empresas mais ricas do mundo', fontsize=25)
plt.xlabel('Empresas', fontsize=20)
plt.ylabel('Bilhões', fontsize=20)
plt.legend(['Bilhões de dólares'], loc = 'right', fontsize=15)
plt.grid(True)
plt.show()

# %%
#mudando o tipo do gráfico e colocando e legenda acima (plt.bar)
plt.bar(empresas, bilhoes, color = 'blue')
plt.title('Empresas mais ricas do mundo', fontsize=25)
plt.xlabel('Empresas', fontsize=20)
plt.ylabel('Bilhões', fontsize=20)
plt.legend(['Bilhões de dólares'], loc = 'high right', fontsize=15)
plt.grid(True)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: MatplotlibDeprecationWarning: Unrecognized location 'high right'. Falling back on 'best'; valid locations are
# 	best
# 	upper right
# 	upper left
# 	lower left
# 	lower right
# 	right
# 	center left
# 	center right
# 	lower center
# 	upper center
# 	center
# This will raise an exception in 3.3.

# %%
#gráfico mais simples
plt.bar(empresas, bilhoes)
# Out:
# <BarContainer object of 10 artists>

# %%
cores = ['red',  'yellow', 'green', 'blue', 'purple', 'orange', 'magenta', 'white', 'brown', 'black']

# %%
cores2 = ['dimgray', 'dimgrey', 'gray', 'grey', 'darkgray', 'darkgrey', 'silver', 'lightgray', 'lightgrey', 'gainsboro']

# %%
plt.bar(empresas, bilhoes, color = cores, edgecolor='black')
plt.title('Empresas mais ricas do mundo', fontsize=25)
plt.xlabel('Empresas', fontsize=20)
plt.ylabel('Bilhões de dólares', fontsize=20)
plt.legend(['Bilhões de dólares'], loc = 'high right', fontsize=15)
plt.grid(True)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: MatplotlibDeprecationWarning: Unrecognized location 'high right'. Falling back on 'best'; valid locations are
# 	best
# 	upper right
# 	upper left
# 	lower left
# 	lower right
# 	right
# 	center left
# 	center right
# 	lower center
# 	upper center
# 	center
# This will raise an exception in 3.3.
#   """

# %%
plt.bar(empresas, bilhoes, color = cores2, edgecolor='black')
plt.title('Empresas mais ricas do mundo', fontsize=25)
plt.xlabel('Empresas', fontsize=20)
plt.ylabel('Bilhões de dólares', fontsize=20)
plt.legend(['Bilhões de dólares'], loc = 'high right', fontsize=15)
plt.grid(True)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: MatplotlibDeprecationWarning: Unrecognized location 'high right'. Falling back on 'best'; valid locations are
# 	best
# 	upper right
# 	upper left
# 	lower left
# 	lower right
# 	right
# 	center left
# 	center right
# 	lower center
# 	upper center
# 	center
# This will raise an exception in 3.3.
#   """

# %%
#estilo do gráfico
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use('grayscale')
plt.bar(empresas, bilhoes, color = cores2, edgecolor='black')
plt.title('Empresas mais ricas do mundo', fontsize=25)
plt.xlabel('Empresas', fontsize=20)
plt.ylabel('Bilhões de dólares', fontsize=20)
plt.legend(['Bilhões de dólares'], loc = 'high right', fontsize=15)
plt.grid(True)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: MatplotlibDeprecationWarning: Unrecognized location 'high right'. Falling back on 'best'; valid locations are
# 	best
# 	upper right
# 	upper left
# 	lower left
# 	lower right
# 	right
# 	center left
# 	center right
# 	lower center
# 	upper center
# 	center
# This will raise an exception in 3.3.

# %%
#barh
plt.style.use('grayscale')
plt.barh(empresas, bilhoes, color = cores2, edgecolor='black')
plt.title('Empresas mais ricas do mundo', fontsize=25)
plt.xlabel('Empresas', fontsize=20)
plt.ylabel('Bilhões de dólares', fontsize=20)
plt.legend(['Bilhões de dólares'], loc = 'high right', fontsize=15)
plt.grid(True)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: MatplotlibDeprecationWarning: Unrecognized location 'high right'. Falling back on 'best'; valid locations are
# 	best
# 	upper right
# 	upper left
# 	lower left
# 	lower right
# 	right
# 	center left
# 	center right
# 	lower center
# 	upper center
# 	center
# This will raise an exception in 3.3.
#   import sys

# %%
plt.style.use('grayscale')
plt.scatter(empresas, bilhoes, color = cores, edgecolor='black')
plt.title('Empresas mais ricas do mundo', fontsize=25)
plt.xlabel('Empresas', fontsize=20)
plt.ylabel('Bilhões de dólares', fontsize=20)
plt.legend(['Bilhões de dólares'], loc = 'high right', fontsize=15)
plt.grid(True)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: MatplotlibDeprecationWarning: Unrecognized location 'high right'. Falling back on 'best'; valid locations are
# 	best
# 	upper right
# 	upper left
# 	lower left
# 	lower right
# 	right
# 	center left
# 	center right
# 	lower center
# 	upper center
# 	center
# This will raise an exception in 3.3.
